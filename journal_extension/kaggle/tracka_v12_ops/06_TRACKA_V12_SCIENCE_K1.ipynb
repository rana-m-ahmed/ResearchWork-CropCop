# %% [markdown]
# # Track-A v1.2 — Scientific Execution K1
#
# Scientific continuation for account K1. Select **GPU T4 x2**, enable Internet, attach frozen V1, the complete G1A bundle, and the execution-control bundle. Add Kaggle credentials for the same account that owned K1's G2A durability datasets.
#
# **Frozen science SHA:** `9a72e9466a9a3e7429e0e36a028edac662f83146`
# **Pinned operator runtime:** `200dd76b00201b81630ce4877d8b3197c6b687cc`

# %%
# Optional path overrides; use only if exact auto-discovery is ambiguous.
# import os
# os.environ['CROPCOP_MANIFEST'] = '/kaggle/input/.../dataset_manifest.csv'
# os.environ['CROPCOP_CLASS_MAP'] = '/kaggle/input/.../class_index.json'
# os.environ['CROPCOP_IMAGE_ROOT'] = '/kaggle/input/.../image-root'
# os.environ['CROPCOP_G1A_BUNDLE'] = '/kaggle/input/.../TRACKA_V12_G1A_BUNDLE'

# %%
from pathlib import Path
import shutil, subprocess, sys
OPS_RUNTIME_SHA = "200dd76b00201b81630ce4877d8b3197c6b687cc"
OPS_RUNTIME_BRANCH = "ops-tracka-kaggle-runtime-v2.2-200dd76"
OPS_ROOT = Path("/kaggle/working/cropcop-ops-runtime")
if OPS_ROOT.exists(): shutil.rmtree(OPS_ROOT)
subprocess.run(["git","clone","--quiet","--depth","1","--branch",OPS_RUNTIME_BRANCH,"https://github.com/rana-m-ahmed/ResearchWork-CropCop.git",str(OPS_ROOT)], check=True)
head = subprocess.check_output(["git","rev-parse","HEAD"], cwd=OPS_ROOT, text=True).strip()
dirty = subprocess.check_output(["git","status","--porcelain"], cwd=OPS_ROOT, text=True).strip()
if head != OPS_RUNTIME_SHA: raise RuntimeError(f"operator runtime SHA mismatch: expected {OPS_RUNTIME_SHA}, got {head}")
if dirty: raise RuntimeError(f"operator runtime checkout is dirty:\n{dirty}")
print("Pinned Track-A operator runtime:", head)

# %%
driver = OPS_ROOT / "journal_extension/kaggle/tracka_v12_ops/science_account_driver.py"
cp = subprocess.run([sys.executable, str(driver), "K1"], cwd=driver.parent)
if cp.returncode not in {0, 2}: raise RuntimeError(f"operator driver failed with rc={cp.returncode}")
if cp.returncode == 2:
    print("Planned session rollover: start a fresh Kaggle session with the same mounted inputs and rerun this notebook.")
else:
    print("Account scientific queue reached terminal PASS.")

# %% [markdown]
# Return code 0 means the account queue is terminal PASS. Return code 2 is accepted only when the wrapper independently verifies an explicit planned session rollover; restart in a fresh Kaggle session with the same account and inputs.
